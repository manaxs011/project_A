# %% [markdown]
# <a href="https://colab.research.google.com/github/manaxs011/project_A/blob/main/car_sellingprice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loading libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
print(df.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
#checking missing value
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#checking value counts of a column
df['Car_Name'].value_counts()
# Out:
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64

# %%
df['Seller_Type'].value_counts()
# Out:
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64

# %%
plt.hist(df['Year'],width=1)
# Out:
# (array([  3.,   4.,   6.,   7.,  21.,  19.,  56.,  38., 111.,  36.]),
#  array([2003. , 2004.5, 2006. , 2007.5, 2009. , 2010.5, 2012. , 2013.5,
#         2015. , 2016.5, 2018. ]),
#  <a list of 10 Patch objects>)

# %%
df['Transmission'].value_counts().plot.pie()

# %%
sns.countplot(x="Fuel_Type",data=df)
plt.title('vehicle fuel type')
plt.show()

# %%
#checking corelation
corelation=df.corr()
sns.heatmap(corelation)
plt.title('heatmap')
# Out:
# Text(0.5, 1.0, 'heatmap')

# %%
sns.jointplot(x='Selling_Price',y='Present_Price',data=df)

# %%
#GET DUMMY -to convert categorical variable into dummy or indicator variable
dummy=pd.get_dummies(df[['Fuel_Type','Transmission','Seller_Type']],drop_first=True)
dummy
# Out:
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Manual  \
# 0                   0                 1                    1
# 1                   1                 0                    1
# 2                   0                 1                    1
# 3                   0                 1                    1
# 4                   1                 0                    1
# ..                ...               ...                  ...
# 296                 1                 0                    1
# 297                 0                 1                    1
# 298                 0                 1                    1
# 299                 1                 0                    1
# 300                 0                 1                    1
#
#      Seller_Type_Individual
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ..                      ...
# ...

# %%
#concatenation for data manipulation
df1=pd.concat([df,dummy],axis=1)
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# ...

# %%
#we are droping unwanted columns
df2=df1.drop(['Car_Name','Fuel_Type','Seller_Type','Transmission'],axis=1)
df2
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0    2014           3.35           5.59       27000      0                 0
# 1    2013           4.75           9.54       43000      0                 1
# 2    2017           7.25           9.85        6900      0                 0
# 3    2011           2.85           4.15        5200      0                 0
# 4    2014           4.60           6.87       42450      0                 1
# ..    ...            ...            ...         ...    ...               ...
# 296  2016           9.50          11.60       33988      0                 1
# 297  2015           4.00           5.90       60000      0                 0
# 298  2009           3.35          11.00       87934      0                 0
# 299  2017          11.50          12.50        9000      0                 1
# 300  2016           5.30           5.90        5464      0                 0
#
# ...

# %%
# seperating input and output
x=df2.drop(['Selling_Price'],axis=1)
x
# Out:
#      Year  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0    2014           5.59       27000      0                 0
# 1    2013           9.54       43000      0                 1
# 2    2017           9.85        6900      0                 0
# 3    2011           4.15        5200      0                 0
# 4    2014           6.87       42450      0                 1
# ..    ...            ...         ...    ...               ...
# 296  2016          11.60       33988      0                 1
# 297  2015           5.90       60000      0                 0
# 298  2009          11.00       87934      0                 0
# 299  2017          12.50        9000      0                 1
# 300  2016           5.90        5464      0                 0
#
#      Fuel_Type_Petrol  Transmission_Manual  Seller_Type_Individual
# 0                   1                    1                       0
# 1                   0                    1                       0
# ...

# %%
y=df2['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
sns.regplot(x=df['Present_Price'],y=y,color='g')

# %%
#seperating training and testing data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
#preprocessing
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scalar.fit(x_train)
x_train=scalar.transform(x_train)
x_test=scalar.transform(x_test)

# %%
#model building
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 7.73693158e+00,  2.91761657e+00, -5.91130635e-01,  4.16651169e+00,
#         5.09900037e-01,  5.78898134e+00,  1.99706635e+00,  2.51236068e+00,
#         7.71358848e+00,  1.02641288e+00,  8.09286458e+00,  3.48679263e+00,
#         4.85485512e+00,  4.78169982e+00, -1.97334513e+00,  3.09825075e+00,
#         7.97355424e+00,  6.72501538e+00,  6.78464840e+00,  7.99850336e+00,
#         4.38898387e+00,  3.96162782e+00,  1.12674464e+01,  7.95211562e+00,
#         1.01591802e+01,  3.52293119e+00,  3.81889428e+00,  1.10156677e+00,
#        -5.34605528e-01, -5.92078964e-01,  4.15437805e-02, -1.26336183e+00,
#         4.25154365e+00,  2.06573574e+01,  1.87211472e+01,  4.24972693e+00,
#         3.44272911e+00,  1.70420345e+00,  1.49588147e-01,  5.65034705e+00,
#         8.06939245e+00,  9.87765725e+00,  6.09562912e-01,  6.03967791e+00,
#         5.87242019e+00,  4.29640668e+00,  7.35369767e+00,  5.85186936e+00,
# ...

# %%
#compare actual value and predicted value by creating new dataframe
df3=pd.DataFrame({'actual_value':y_test,'prediced_value':y_pred})
df3
# Out:
#      actual_value  prediced_value
# 285          7.40        7.736932
# 248          4.00        2.917617
# 150          0.50       -0.591131
# 217          3.15        4.166512
# 107          1.25        0.509900
# ..            ...             ...
# 225          2.70        2.107705
# 138          0.60        1.493431
# 127          0.75        1.495806
# 208          7.90        6.254636
# 280          5.25        4.396914
#
# [91 rows x 2 columns]

# %%
print('slop is',model.coef_)
print('constant is',model.intercept_)
# Out:
# slop is [ 1.22892122  4.0342602  -0.18209819  0.07808457  0.87226802  0.17314277
#  -0.6032581  -0.52312819]
# constant is 4.74880952380956

# %%
#Perform evaluation 
#mean absolute error
from sklearn.metrics import mean_absolute_error
print('mean absoulte error is',mean_absolute_error(y_test,y_pred))
# Out:
# mean absoulte error is 1.1013566874987437

# %%
#mean absolute percentage error
from sklearn.metrics import mean_absolute_percentage_error
print('mean absolute percentage error is',mean_absolute_percentage_error(y_test,y_pred))
# Out:
# mean absolute percentage error is 1.0122381316606566

# %%
#mean squared error
from sklearn.metrics import mean_squared_error
print('mean squared error is',mean_squared_error(y_test,y_pred))
# Out:
# mean squared error is 2.779453229197401

# %%
#root mean squared_error
from sklearn.metrics import mean_squared_error
k=mean_squared_error(y_test,y_pred)
c=np.sqrt(k)
print('root mean squared error is',c)
# Out:
# root mean squared error is 1.6671692263226912
