# %% [markdown]
# <a href="https://colab.research.google.com/github/manaxs011/projects-on-ml/blob/main/Exercize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("/content/calories.csv")
df
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68     190    94.0      29.0         105       40.8
# 1      14861698  female   20     166    50.0      14.0          94       40.3
# 2      11179863    male   69     179    79.0       5.0          88       38.7
# 3      16180408  female   34     179    71.0      13.0         100       40.5
# 4      17771927  female   27     154    58.0      10.0          81       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20     193    86.0      11.0          92       40.4
# 14996  17212577  female   27     165    65.0       6.0          85       39.2
# 14997  17271188  female   43     159    58.0      16.0          90       40.1
# 14998  18643037    male   78     193    97.0       2.0          84       38.3
# 14999  11751526    male   63     173    79.0      18.0          92       40.5
#
#        Calories
# ...

# %%
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68     190    94.0      29.0         105       40.8
# 1  14861698  female   20     166    50.0      14.0          94       40.3
# 2  11179863    male   69     179    79.0       5.0          88       38.7
# 3  16180408  female   34     179    71.0      13.0         100       40.5
# 4  17771927  female   27     154    58.0      10.0          81       39.8
#
#    Calories
# 0       231
# 1        66
# 2        26
# 3        71
# 4        35

# %%
df.tail()
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 14995  15644082  female   20     193    86.0      11.0          92       40.4
# 14996  17212577  female   27     165    65.0       6.0          85       39.2
# 14997  17271188  female   43     159    58.0      16.0          90       40.1
# 14998  18643037    male   78     193    97.0       2.0          84       38.3
# 14999  11751526    male   63     173    79.0      18.0          92       40.5
#
#        Calories
# 14995        45
# 14996        23
# 14997        75
# 14998        11
# 14999        98

# %%
# checking the number of rows and columns
df.shape
# Out:
# (15000, 9)

# %%
# getting some informations about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  int64
#  4   Weight      14884 non-null  float64
#  5   Duration    14913 non-null  float64
#  6   Heart_Rate  15000 non-null  int64
#  7   Body_Temp   14179 non-null  float64
#  8   Calories    15000 non-null  int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 1.0+ MB

# %%
# checking for missing values
df.isna().sum()
# Out:
# User_ID         0
# Gender          0
# Age             0
# Height          0
# Weight        116
# Duration       87
# Heart_Rate      0
# Body_Temp     821
# Calories        0
# dtype: int64

# %%
# get some statistical measures about the data
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  14884.000000  14913.000000
# mean   1.497736e+07     42.789800    174.465133     75.003091     15.528867
# std    2.872851e+06     16.980264     14.258114     15.047980      8.322576
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  14179.000000  15000.000000
# mean      95.518533     40.025594     89.539533
# std        9.583328      0.779738     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
#fill missing values
df['Weight']=df['Weight'].fillna(df['Weight'].mean())
df['Duration']=df['Duration'].fillna(df['Duration'].mean())
df['Body_Temp']=df['Body_Temp'].fillna(df['Body_Temp'].mean())
df.isna().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %% [markdown]
# **Data Visualization**

# %%
# plotting the gender column in count plot
sns.countplot(df['Gender'])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
# finding the distribution of "Age" column
sns.distplot(df['Age'])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Height'],color='green')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
plt.hist(df['Calories'],width=20)
plt.xlabel('calories burned')
# Out:
# Text(0.5, 0, 'calories burned')

# %%
#checking corelation
corelation=df.corr()
sns.heatmap(corelation,cmap='Blues')
plt.title('heatmap',color='blue')
# Out:
# Text(0.5, 1.0, 'heatmap')

# %%
sns.jointplot(x='Height',y='Weight',data=df)

# %%
df1=df.drop(['User_ID'],axis=1)
df1.head()
# Out:
#    Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0    male   68     190    94.0      29.0         105       40.8       231
# 1  female   20     166    50.0      14.0          94       40.3        66
# 2    male   69     179    79.0       5.0          88       38.7        26
# 3  female   34     179    71.0      13.0         100       40.5        71
# 4  female   27     154    58.0      10.0          81       39.8        35

# %%
#Converting gender column to numerical values
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1['Gender']=le.fit_transform(df['Gender'])
df1.head()
# Out:
#    Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0       1   68     190    94.0      29.0         105       40.8       231
# 1       0   20     166    50.0      14.0          94       40.3        66
# 2       1   69     179    79.0       5.0          88       38.7        26
# 3       0   34     179    71.0      13.0         100       40.5        71
# 4       0   27     154    58.0      10.0          81       39.8        35

# %%
# seperating input and output
x=df1.iloc[:,:-1]
y=df1.iloc[:,-1]
x.tail()
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 14995       0   20     193    86.0      11.0          92       40.4
# 14996       0   27     165    65.0       6.0          85       39.2
# 14997       0   43     159    58.0      16.0          90       40.1
# 14998       1   78     193    97.0       2.0          84       38.3
# 14999       1   63     173    79.0      18.0          92       40.5

# %%
#seperating training and testing data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (15000, 7) (10500, 7) (4500, 7)

# %% [markdown]
# **Prediction on Test Data Using DecisionTree Algorithm**

# %%
#using DecisionTree algorithm
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
#compare actual value and predicted value by creating new dataframe
df2=pd.DataFrame({'actual_value':y_test,'prediced_value':y_pred})
df2
# Out:
#        actual_value  prediced_value
# 11499           173           164.0
# 6475            189           187.0
# 13167            53            52.0
# 862             161           162.0
# 5970            226           221.0
# ...             ...             ...
# 4217             40            45.0
# 13886            38            40.0
# 10464            30            26.0
# 6902            198           227.0
# 4874            138           134.0
#
# [4500 rows x 2 columns]

# %%
#Perform evaluation 
#mean absolute error
from sklearn.metrics import mean_absolute_error
print('mean absoulte error is',mean_absolute_error(y_test,y_pred))
# Out:
# mean absoulte error is 3.6264444444444446

# %%
#mean absolute percentage error
from sklearn.metrics import mean_absolute_percentage_error
print('mean absolute percentage error is',mean_absolute_percentage_error(y_test,y_pred))
# Out:
# mean absolute percentage error is 0.0494537816578041

# %%
#mean squared error
from sklearn.metrics import mean_squared_error
print('mean squared error is',mean_squared_error(y_test,y_pred))
# Out:
# mean squared error is 38.275777777777776

# %%
#root mean squared_error
from sklearn.metrics import mean_squared_error
k=mean_squared_error(y_test,y_pred)
c=np.sqrt(k)
print('root mean squared error is',c)
# Out:
# root mean squared error is 6.186742097241308
